# %% [markdown]
# <a href="https://colab.research.google.com/github/anissa762/goldfish/blob/main/goldfish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%
# Install necessary libraries
# !pip install --upgrade optuna ta tensorflow torch torchvision
# !pip install keras
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: ta in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.18.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ta) (2.2.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.8)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.5.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# %%
# Import Libraries
import pandas as pd
import numpy as np
import glob
import os
from datetime import datetime, timedelta

# Machine Learning Libraries
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# For Technical Indicators
import ta

# For Optuna Hyperparameter Tuning
import optuna
from optuna.pruners import MedianPruner
from optuna.exceptions import TrialPruned

# TensorFlow Libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

# PyTorch Libraries
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# For saving/loading data
import pickle

# Suppress warnings for cleaner output
import warnings
warnings.filterwarnings('ignore')

# %%
# %%
# Mount Google Drive for persistent storage
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%
# Define paths
DATA_PATH = '/content/drive/MyDrive/data/'
STUDIES_DIR = os.path.join(DATA_PATH, 'optuna_studies')
FORECASTS_PATH = os.path.join(DATA_PATH, 'stock_forecasts.pkl')
PERFORMANCE_PATH = os.path.join(DATA_PATH, 'model_performance.pkl')
BEST_PARAMS_PATH = os.path.join(DATA_PATH, 'best_params_dict.pkl')
ELECTION_DATA_PATH = '/content/drive/MyDrive/final_stock_rankings.csv'

# Create necessary directories if they don't exist
os.makedirs(STUDIES_DIR, exist_ok=True)

# %%
# %%
# Load existing best parameters if available
if os.path.exists(BEST_PARAMS_PATH):
    with open(BEST_PARAMS_PATH, 'rb') as f:
        best_params_dict = pickle.load(f)
    print("Loaded existing best parameters.")
else:
    best_params_dict = {}
    print("No existing best parameters found. Starting fresh.")
# Out:
# Loaded existing best parameters.

# %%
# %%
# Load existing forecasts
if os.path.exists(FORECASTS_PATH):
    with open(FORECASTS_PATH, 'rb') as f:
        stock_forecasts = pickle.load(f)
    print("Loaded existing forecasts.")
else:
    stock_forecasts = {}
    print("No existing forecasts found. Starting fresh.")
# Out:
# Loaded existing forecasts.

# %%
# %%
# Load existing model performance data
if os.path.exists(PERFORMANCE_PATH):
    with open(PERFORMANCE_PATH, 'rb') as f:
        model_performance = pickle.load(f)
    print("Loaded existing model performance data.")
else:
    model_performance = []
    print("No existing model performance data found. Starting fresh.")
# Out:
# Loaded existing model performance data.

# %%
# %%
# List all CSV files in the directory
csv_files = glob.glob(os.path.join(DATA_PATH, '*_data_cleaned.csv'))

print(f"Total CSV files found: {len(csv_files)}")
# Out:
# Total CSV files found: 260

# %%
# %%
# List all CSV files in the directory
csv_files = glob.glob(os.path.join(DATA_PATH, '*_data_cleaned.csv'))

print(f"Total CSV files found: {len(csv_files)}")
# Out:
# Total CSV files found: 260

# %%
# %%
# Initialize a dictionary to store DataFrames
stock_data = {}

# Feature Engineering Function
def add_technical_indicators(df):
    df = df.copy()

    # Moving Averages
    df['MA10'] = df['Close'].rolling(window=10).mean()
    df['MA50'] = df['Close'].rolling(window=50).mean()

    # Relative Strength Index
    df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

    # Moving Average Convergence Divergence
    macd = ta.trend.MACD(df['Close'])
    df['MACD'] = macd.macd()
    df['MACD_signal'] = macd.macd_signal()
    df['MACD_diff'] = macd.macd_diff()

    # Bollinger Bands
    bollinger = ta.volatility.BollingerBands(df['Close'], window=20, window_dev=2)
    df['Bollinger_High'] = bollinger.bollinger_hband()
    df['Bollinger_Low'] = bollinger.bollinger_lband()

    # Volume Indicators
    df['Volume_MA20'] = df['Volume'].rolling(window=20).mean()

    # On-Balance Volume
    df['OBV'] = ta.volume.OnBalanceVolumeIndicator(df['Close'], df['Volume']).on_balance_volume()

    # Exponential Moving Averages
    df['EMA10'] = ta.trend.EMAIndicator(df['Close'], window=10).ema_indicator()
    df['EMA50'] = ta.trend.EMAIndicator(df['Close'], window=50).ema_indicator()

    # Drop initial rows with NaN values due to rolling calculations
    df.dropna(inplace=True)

    return df

# %%
# %%
# Load and preprocess each CSV file
for file in csv_files:
    stock_name = os.path.basename(file).split('_')[0]
    df = pd.read_csv(file)

    # Convert 'Date' column to datetime
    df['Date'] = pd.to_datetime(df['Date'])

    # Sort by Date
    df = df.sort_values('Date')

    # Drop rows with any NA values
    df.dropna(inplace=True)

    # Reset index
    df.reset_index(drop=True, inplace=True)

    # Add technical indicators
    df = add_technical_indicators(df)

    # Store in dictionary
    stock_data[stock_name] = df

print("Data loading and preprocessing completed.")
# Out:
# Data loading and preprocessing completed.

# %%
# %%
# Load Election Impact Data
if os.path.exists(ELECTION_DATA_PATH):
    election_data = pd.read_csv(ELECTION_DATA_PATH)
    print("Loaded election impact data.")
else:
    election_data = pd.DataFrame()
    print("Election impact data not found.")
# Out:
# Loaded election impact data.

# %%
# %%
# Display the first few rows and columns of election impact data to understand its structure
if not election_data.empty:
    print("Election Impact Data Columns:", election_data.columns.tolist())
    display(election_data.head())
else:
    print("No election impact data to display.")
# Out:
# Election Impact Data Columns: ['Ticker', 'InverseCorr2016', 'InverseCorr2020', 'FinalScore']
#   Ticker  InverseCorr2016  InverseCorr2020  FinalScore
# 0    WFC         0.167520        -0.035576    0.203096
# 1    EQT         0.068077        -0.114918    0.182995
# 2      K         0.074987        -0.091078    0.166065
# 3    HPE         0.126264        -0.036836    0.163100
# 4    BAC         0.099325        -0.062520    0.161845

# %%
# %%
# Merge 'FinalScore' into each stock's DataFrame
# First, identify the correct column name for stock identifiers
# Common possibilities include 'Stock', 'Ticker', or 'Symbol'
stock_identifier_cols = ['Stock', 'Ticker', 'Symbol']

# Find which of these columns exists in election_data
existing_id_cols = [col for col in stock_identifier_cols if col in election_data.columns]

if not existing_id_cols:
    raise KeyError(f"None of the expected stock identifier columns {stock_identifier_cols} found in election_data.")
elif len(existing_id_cols) > 1:
    print(f"Multiple identifier columns found: {existing_id_cols}. Using the first one: '{existing_id_cols[0]}'.")
    id_col = existing_id_cols[0]
else:
    id_col = existing_id_cols[0]
    print(f"Using '{id_col}' as the stock identifier column for merging.")

# Define the default ElectionImpact value
DEFAULT_ELECTION_IMPACT = 0  # Represents 'no impact'

# Proceed to merge 'FinalScore' based on the identified stock identifier column
for stock in stock_data:
    # Retrieve the 'FinalScore' for the current stock
    score_series = election_data.loc[election_data[id_col] == stock, 'FinalScore']

    if not score_series.empty:
        election_impact = score_series.values[0]
        print(f"Assigned ElectionImpact for {stock}: {election_impact}")
    else:
        # If 'FinalScore' is not specified for the stock, assign the default impact value
        election_impact = DEFAULT_ELECTION_IMPACT
        print(f"No ElectionImpact specified for {stock}. Assigned default impact value: {0}")

    # Assign 'ElectionImpact' to the DataFrame, even if it's empty
    # This ensures the column exists for all DataFrames
    stock_data[stock]['ElectionImpact'] = election_impact
# Out:
# Using 'Ticker' as the stock identifier column for merging.
# Assigned ElectionImpact for XYL: -0.0020828702201409
# Assigned ElectionImpact for WSM: 0.0654784830021114
# Assigned ElectionImpact for WMB: -0.0337722429916873
# Assigned ElectionImpact for WST: 0.0552518798394123
# Assigned ElectionImpact for XOM: -0.0341210206746801
# Assigned ElectionImpact for WY: 0.1239767103734074
# Assigned ElectionImpact for WFC: 0.2030960160762678
# Assigned ElectionImpact for WTW: 0.1126134281430669
# Assigned ElectionImpact for WDC: 0.1162450134542883
# Assigned ElectionImpact for ZBH: 0.0520346518539104
# Assigned ElectionImpact for WBD: 0.0379008483854373
# Assigned ElectionImpact for WELL: 0.0077327173983179
# Assigned ElectionImpact for WDAY: 0.0792028281862628
# Assigned ElectionImpact for VZ: 0.015503175866263
# Assigned ElectionImpact for WAT: -0.0389472240845118
# Assigned ElectionImpact for V: 0.0850969349459994
# Assigned ElectionImpact for VEEV: -0.0049466658406312
# Assigned ElectionImpact for URI: 0.1395217100292884
# Assigned ElectionImpact for USB: 0.0319946302443736
# Assigned ElectionImpact for VRTX: -0.0398686443106492
# Assigned ElectionImpact for TEAM: 0.0214784740817419
# Assigned ElectionImpact for TRGP: -0.037323356216515
# Assigned ElectionImpact for TFC: 0.0482709610109921
# Assigned ElectionImpact for TSLA: -0.0258233808371628
# Assigned ElectionImpact for TRMB: 0.0950904254996182
# Assigned ElectionImpact for UNH: 0.0409256661670681
# Assigned ElectionImpact for SPGI: 0.0761196723024423
# Assigned ElectionImpact for SYF: 0.0368858429046523
# Assigned ElectionImpact for TT: -0.0362807811872671
# Assigned ElectionImpact for UNP: -0.0792504775178135
# Assigned ElectionImpact for SYK: 0.116613765821968
# Assigned ElectionImpact for UPS: 0.0394008238726188
# Assigned ElectionImpact for SYY: 0.122861947718427
# Assigned ElectionImpact for TGT: 0.0200165014466134
# Assigned ElectionImpact for TAP: 0.0492612499729639
# Assigned ElectionImpact for TWLO: -0.0029303183722378
# Assigned ElectionImpact for TSCO: 0.1367605027987906
# Assigned ElectionImpact for TXN: -0.0413294474064384
# Assigned ElectionImpact for TRV: -0.1051787527008142
# Assigned ElectionImpact for T: -0.0356650841378988
# Assigned ElectionImpact for SBUX: -0.0369455334396563
# Assigned ElectionImpact for PNC: 0.0946371205996052
# Assigned ElectionImpact for QCOM: -0.045130076781243
# Assigned ElectionImpact for PTC: 0.0079518811985805
# Assigned ElectionImpact for PPG: 0.0812453970720952
# Assigned ElectionImpact for PWR: -0.0160418693491779
# Assigned ElectionImpact for PRU: 0.0967856958198255
# Assigned ElectionImpact for RCL: -0.0706163152457605
# Assigned ElectionImpact for STE: -0.0246310702517542
# Assigned ElectionImpact for SLB: 0.076318359149467
# Assigned ElectionImpact for SCHW: 0.1189186667604089
# Assigned ElectionImpact for SBAC: 0.1067971850142185
# Assigned ElectionImpact for PYPL: 0.0424591399395166
# Assigned ElectionImpact for RTX: 0.0201552119073294
# Assigned ElectionImpact for REGN: -0.1176520502766617
# Assigned ElectionImpact for PSX: -0.0429639010563495
# Assigned ElectionImpact for POOL: -0.0594479095837184
# Assigned ElectionImpact for SNPS: -0.0620498605094078
# Assigned ElectionImpact for PNR: 0.0807841322081194
# Assigned ElectionImpact for RJF: 0.109388005772132
# Assigned ElectionImpact for PLD: 0.0853261649502499
# Assigned ElectionImpact for PEG: 0.0881163138911968
# Assigned ElectionImpact for PANW: 0.0699781729738899
# Assigned ElectionImpact for PEP: 0.1495666607187243
# Assigned ElectionImpact for PG: 0.0410708230512217
# Assigned ElectionImpact for PHM: -0.0059323141089722
# Assigned ElectionImpact for PFE: -0.1198051773568806
# Assigned ElectionImpact for PGR: -0.0577246246908211
# Assigned ElectionImpact for NFLX: -0.0228670931618616
# Assigned ElectionImpact for NEE: 0.1097510852594276
# Assigned ElectionImpact for ODFL: 0.0650622219395086
# Assigned ElectionImpact for OC: -0.0017591937016171
# Assigned ElectionImpact for NVDA: -0.01178985338793
# Assigned ElectionImpact for NI: 0.0868440550451514
# Assigned ElectionImpact for OVV: 0.0533970266852128
# Assigned ElectionImpact for NEM: 0.1235738272800903
# Assigned ElectionImpact for NDAQ: 0.052227571304042
# Assigned ElectionImpact for MOS: 0.0343779127399555
# Assigned ElectionImpact for ORCL: 0.0315902441232872
# Assigned ElectionImpact for MRK: 0.0134844230612061
# Assigned ElectionImpact for MU: 0.044023170931096
# Assigned ElectionImpact for NUE: -0.1478083040373362
# Assigned ElectionImpact for OKE: 0.1087595665687419
# Assigned ElectionImpact for NOW: 0.1153841704625696
# Assigned ElectionImpact for NXPI: 0.0851624180046958
# Assigned ElectionImpact for MMM: 0.0508639999933483
# Assigned ElectionImpact for NTAP: 0.0552284309081948
# Assigned ElectionImpact for NOC: 0.0519197905545117
# Assigned ElectionImpact for MSTR: -0.1430661652089244
# Assigned ElectionImpact for MS: 0.0894968634646052
# Assigned ElectionImpact for LLY: -0.0939990048818632
# Assigned ElectionImpact for LKQ: 0.1102839131593151
# Assigned ElectionImpact for META: -0.0962597901385414
# Assigned ElectionImpact for MKC: 0.0594037593038375
# Assigned ElectionImpact for LH: -0.0111925059851142
# Assigned ElectionImpact for MSFT: 0.0814825560909124
# Assigned ElectionImpact for MMC: 0.1167923569964182
# Assigned ElectionImpact for MLM: -0.0448199434105972
# Assigned ElectionImpact for MET: 0.0553903735930404
# Assigned ElectionImpact for MCO: 0.0493120846717143
# Assigned ElectionImpact for MCD: -0.0710331247267272
# Assigned ElectionImpact for MELI: 0.0136269919800281
# Assigned ElectionImpact for MTD: 0.0323268750067
# Assigned ElectionImpact for LII: -0.0106444512716498
# Assigned ElectionImpact for LIN: 0.0897048500591361
# Assigned ElectionImpact for MCK: 0.1146962042279131
# Assigned ElectionImpact for MSI: 0.0856181074953131
# Assigned ElectionImpact for MRVL: 0.106526039481199
# Assigned ElectionImpact for IRM: 0.0433634203165179
# Assigned ElectionImpact for KMI: 0.0058313034137377
# Assigned ElectionImpact for LNG: 0.01241617595711
# Assigned ElectionImpact for JBHT: 0.0485522161115855
# Assigned ElectionImpact for KEYS: 0.0310177677681951
# Assigned ElectionImpact for LULU: -0.2140757611400531
# Assigned ElectionImpact for KKR: 0.1275801658540739
# Assigned ElectionImpact for LRCX: 0.0629234111248906
# Assigned ElectionImpact for KMB: 0.1521040967916238
# Assigned ElectionImpact for KR: 0.0133689881616978
# Assigned ElectionImpact for J: -0.0228096465085988
# Assigned ElectionImpact for KMX: 0.0086286164231818
# Assigned ElectionImpact for IT: 0.0048600087938269
# Assigned ElectionImpact for KO: 0.10544519736344
# Assigned ElectionImpact for LDOS: 0.0265776065110904
# Assigned ElectionImpact for MA: 0.0282484437663318
# Assigned ElectionImpact for LOW: 0.054665455462526
# Assigned ElectionImpact for ISRG: 0.0676930781418126
# Assigned ElectionImpact for KHC: 0.115323978118963
# Assigned ElectionImpact for K: 0.1660650339352751
# Assigned ElectionImpact for AMT: 0.0663792642807609
# Assigned ElectionImpact for AAPL: -0.07958347844061
# Assigned ElectionImpact for BXP: 0.0555758121919321
# Assigned ElectionImpact for BKNG: -0.0034152964390177
# Assigned ElectionImpact for CAH: 0.0557331097863923
# Assigned ElectionImpact for ALNY: 0.029620813728629
# Assigned ElectionImpact for AFL: 0.0065627091544586
# Assigned ElectionImpact for ANET: 0.0399344510332604
# Assigned ElectionImpact for BBY: -0.0002732945600054
# Assigned ElectionImpact for ANSS: 0.0360368053476616
# Assigned ElectionImpact for BALL: -0.0146430327963418
# Assigned ElectionImpact for ACGL: 0.0166545139209446
# Assigned ElectionImpact for AXON: -0.0894318029774799
# Assigned ElectionImpact for BKR: 0.0639085641735841
# Assigned ElectionImpact for AMD: 0.0987827698102474
# Assigned ElectionImpact for AIZ: 0.0962471509638787
# Assigned ElectionImpact for A: 0.0576341110305922
# Assigned ElectionImpact for ABBV: 0.0043150878903427
# Assigned ElectionImpact for AVGO: -0.075366116228153
# Assigned ElectionImpact for AMZN: -0.055844754606866
# Assigned ElectionImpact for AJG: -0.1258318750444931
# Assigned ElectionImpact for BMY: 0.0304467016872521
# Assigned ElectionImpact for ADI: -0.032254508873811
# Assigned ElectionImpact for AKAM: 0.037648998956727
# Assigned ElectionImpact for AMAT: -0.0100980677466537
# Assigned ElectionImpact for C: 0.0496740342203873
# Assigned ElectionImpact for APD: 0.0106388650494072
# Assigned ElectionImpact for ADBE: 0.1066829693567583
# Assigned ElectionImpact for CAG: 0.0675655584225043
# Assigned ElectionImpact for AXP: 0.0411248720587312
# Assigned ElectionImpact for BG: -0.041157915207834
# Assigned ElectionImpact for BR: 0.1215657709103996
# Assigned ElectionImpact for ADP: 0.1194178871364646
# Assigned ElectionImpact for BAC: 0.1618451741237797
# Assigned ElectionImpact for ADSK: 0.0022342819533985
# Assigned ElectionImpact for AMGN: 0.0846225078077695
# Assigned ElectionImpact for AON: 0.1066433954981342
# Assigned ElectionImpact for BLK: -0.0539378208533028
# Assigned ElectionImpact for BK: 0.0529855110623227
# Assigned ElectionImpact for AMP: 0.0674097754682522
# Assigned ElectionImpact for CLX: 0.0465602011765552
# Assigned ElectionImpact for CPB: 0.0575306371868513
# Assigned ElectionImpact for CI: 0.000739721223648
# Assigned ElectionImpact for EXC: 0.0923239928200422
# Assigned ElectionImpact for FANG: 0.0482052495899655
# Assigned ElectionImpact for CPRT: 0.021857363562185
# Assigned ElectionImpact for FFIV: -0.0087532446485432
# Assigned ElectionImpact for DLR: -0.0209043757514414
# Assigned ElectionImpact for ETN: 0.0563674890676123
# Assigned ElectionImpact for EQT: 0.1829952651744623
# Assigned ElectionImpact for EW: -0.1574411620719473
# Assigned ElectionImpact for CNC: 0.0752870925490859
# Assigned ElectionImpact for COO: -0.0871764534377861
# Assigned ElectionImpact for CMCSA: 0.0123366386683325
# Assigned ElectionImpact for CSCO: -0.1019648416917483
# Assigned ElectionImpact for ES: 0.1059816624019033
# Assigned ElectionImpact for FDX: 0.1191305346723269
# Assigned ElectionImpact for DE: 0.0792973817529986
# Assigned ElectionImpact for CMS: 0.0353472950304713
# Assigned ElectionImpact for EQIX: 0.0239963876934124
# Assigned ElectionImpact for CRH: 0.0792669445035038
# Assigned ElectionImpact for ECL: 0.0740287038314125
# Assigned ElectionImpact for COR: 0.1016466096365281
# Assigned ElectionImpact for CHD: -0.0129514809651725
# Assigned ElectionImpact for CBRE: 0.1220124695712012
# Assigned ElectionImpact for EXPD: -0.0315918641221524
# Assigned ElectionImpact for CMG: 0.0409800958700625
# Assigned ElectionImpact for CRM: -0.005602621481592
# Assigned ElectionImpact for D: 0.0734042254197491
# Assigned ElectionImpact for COST: -0.1163822920183397
# Assigned ElectionImpact for DAL: -0.0783663795901757
# Assigned ElectionImpact for FERG: 0.0711532590466842
# Assigned ElectionImpact for DFS: -0.0782226375104611
# Assigned ElectionImpact for FDS: -0.0620800609714028
# Assigned ElectionImpact for DECK: -0.0655486500034237
# Assigned ElectionImpact for EIX: 0.0037700130996484
# Assigned ElectionImpact for CCK: -0.0856116586082079
# Assigned ElectionImpact for CHRW: -0.0397446315301749
# Assigned ElectionImpact for CNH: -0.0120476527454478
# Assigned ElectionImpact for CVX: 0.0510587912493599
# Assigned ElectionImpact for FBIN: -0.1174908865272546
# Assigned ElectionImpact for DXCM: -0.1133667322054576
# Assigned ElectionImpact for DGX: -0.0726483070473857
# Assigned ElectionImpact for EA: -0.0324048520290365
# Assigned ElectionImpact for CDNS: 0.0660107053423181
# Assigned ElectionImpact for CMI: 0.1313089652719514
# Assigned ElectionImpact for ELV: 0.0701194202389408
# Assigned ElectionImpact for FI: 0.1206583458436682
# Assigned ElectionImpact for DHR: 0.0490704845667605
# Assigned ElectionImpact for CAT: -0.0161854876791353
# Assigned ElectionImpact for CCI: 0.0229405270368145
# Assigned ElectionImpact for COP: 0.0521634032698808
# Assigned ElectionImpact for EME: -0.0516417638001108
# Assigned ElectionImpact for DIS: 0.0389785932777062
# Assigned ElectionImpact for COF: -0.0171669821823192
# Assigned ElectionImpact for JNPR: 0.093395421404376
# Assigned ElectionImpact for IDXX: 0.0823183060742967
# Assigned ElectionImpact for GWW: -0.0080182628915514
# Assigned ElectionImpact for INTC: 0.0534137664180241
# Assigned ElectionImpact for HUBS: 0.0739088782807815
# Assigned ElectionImpact for HOLX: -0.1014026815752975
# Assigned ElectionImpact for FTV: -0.0213256853837391
# Assigned ElectionImpact for HBAN: 0.0823192480838787
# Assigned ElectionImpact for HD: 0.0534691442219076
# Assigned ElectionImpact for HCA: 0.0663159822938971
# Assigned ElectionImpact for FLUT: -0.0126074927420457
# Assigned ElectionImpact for HES: 0.0548901511933137
# Assigned ElectionImpact for GOOGL: -0.0252025729542728
# Assigned ElectionImpact for JNJ: -0.0288810601726241
# Assigned ElectionImpact for HON: 0.0414457765898381
# Assigned ElectionImpact for JCI: 0.1091849795729896
# Assigned ElectionImpact for HUBB: 0.03468432741721
# Assigned ElectionImpact for GDDY: -0.0010389127965544
# Assigned ElectionImpact for GILD: -0.0177790746793211
# Assigned ElectionImpact for HUM: 0.0288987838270919
# Assigned ElectionImpact for IBM: 0.0541392652502883
# Assigned ElectionImpact for GE: -0.1060476493805121
# Assigned ElectionImpact for FSLR: -0.0756733546199173
# Assigned ElectionImpact for FIS: 0.051270699894559
# Assigned ElectionImpact for HRL: 0.0451332451975192
# Assigned ElectionImpact for FICO: 0.0167403243778192
# Assigned ElectionImpact for HPE: 0.1630997704185295
# Assigned ElectionImpact for IP: -0.0123196448067752
# Assigned ElectionImpact for INTU: -0.04266797389242
# Assigned ElectionImpact for IQV: 0.0941896144711059
# Assigned ElectionImpact for JPM: 0.1023541012877037
# Assigned ElectionImpact for HIG: 0.0108534161254414
# Assigned ElectionImpact for GS: 0.0829363262722365
# Assigned ElectionImpact for HLT: 0.0354920052444884
# Assigned ElectionImpact for HPQ: 0.0135823322428778
# Assigned ElectionImpact for IEX: -0.0429882403062287
# Assigned ElectionImpact for GIS: 0.0955468590061259

# %%
# %%
# Function to determine if a study exists
def study_exists(study_name, storage_name):
    from optuna.storages import RDBStorage
    try:
        storage = RDBStorage(url=storage_name)
        storage.get_study_id_from_name(study_name)
        return True
    except KeyError:
        return False

# %%
N_TRIALS_GB = 15

# %%
# %%
# Loop through each stock and train Gradient Boosting model
for stock in stock_data:
    # Skip if the stock has already been processed
    if stock in stock_forecasts and 'GradientBoosting' in stock_forecasts[stock]:
        print(f"Skipping Gradient Boosting for {stock} as it has already been processed.")
        continue

    print(f"\nProcessing Gradient Boosting model for stock: {stock}")
    df = stock_data[stock]

    # Define features and target
    feature_cols = ['Open', 'Close', 'High', 'Low', 'Volume', 'MA10', 'MA50', 'RSI',
                   'MACD', 'MACD_signal', 'MACD_diff', 'Bollinger_High', 'Bollinger_Low',
                   'Volume_MA20', 'OBV', 'EMA10', 'EMA50', 'ElectionImpact']

    X = df[feature_cols]
    y = df['Close']

    # Define study name and storage
    study_name = f"gb_study_{stock}"
    storage_name = f"sqlite:///{STUDIES_DIR}/gb_study_{stock}.db"

    # Check if the study already exists
    if study_exists(study_name, storage_name):
        study = optuna.load_study(study_name=study_name, storage=storage_name)
        print(f"Loaded existing Gradient Boosting study for {stock}.")
    else:
        study = optuna.create_study(direction='minimize', study_name=study_name, storage=storage_name, load_if_exists=True, pruner=MedianPruner())
        print(f"Created new Gradient Boosting study for {stock}.")

    # Define the objective function within the loop to capture current X and y
    def objective_gb(trial):
        param = {
            'n_estimators': trial.suggest_int('n_estimators', 100, 500),
            'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.2),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
            'min_samples_split': trial.suggest_int('min_samples_split', 2, 20)
        }
        model = GradientBoostingRegressor(**param, random_state=42)
        tscv = TimeSeriesSplit(n_splits=5)
        mse_scores = []
        for i, (train_index, test_index) in enumerate(tscv.split(X)):
            X_train, X_val = X.iloc[train_index], X.iloc[test_index]
            y_train, y_val = y.iloc[train_index], y.iloc[test_index]
            model.fit(X_train, y_train)
            preds = model.predict(X_val)
            mse = mean_squared_error(y_val, preds)
            mse_scores.append(mse)
            # Report intermediate objective value
            trial.report(mse, i+1)
            # Prune trial if not promising
            if trial.should_prune():
                raise TrialPruned()
        return np.mean(mse_scores)

    try:
        # Optimize hyperparameters using Optuna without SklearnPruningCallback
        study.optimize(objective_gb, n_trials=N_TRIALS_GB, timeout=1800)

        best_params = study.best_params
        print(f"Best params for {stock} (Gradient Boosting): {best_params}")

        # Save best parameters
        best_params_dict.setdefault(stock, {})
        best_params_dict[stock]['GradientBoosting'] = best_params

        # Train the best model on the entire dataset
        best_model = GradientBoostingRegressor(**best_params, random_state=42)
        best_model.fit(X, y)

        # Forecasting: Predict the Close price on the next day
        forecast_close = best_model.predict(X.iloc[-1].values.reshape(1, -1))[0]

        # Store the forecast
        stock_forecasts.setdefault(stock, {})
        stock_forecasts[stock]['GradientBoosting'] = forecast_close

        # Store performance
        model_performance.append({'Stock': stock, 'Model': 'GradientBoosting', 'RMSE': study.best_value})

        print(f"Completed Gradient Boosting for {stock}. Forecast: {forecast_close}")

    except TrialPruned:
        print(f"Gradient Boosting trial for {stock} was pruned.")
    except Exception as e:
        print(f"An error occurred while processing Gradient Boosting for {stock}: {e}")

    # Save the best parameters
    with open(BEST_PARAMS_PATH, 'wb') as f:
        pickle.dump(best_params_dict, f)

    # Save the forecasts and performance after each stock
    with open(FORECASTS_PATH, 'wb') as f:
        pickle.dump(stock_forecasts, f)

    with open(PERFORMANCE_PATH, 'wb') as f:
        pickle.dump(model_performance, f)

    print(f"Saved Gradient Boosting parameters, forecasts, and performance data for {stock}.")

print("\nGradient Boosting model training and forecasting completed.")
# Out:
# Skipping Gradient Boosting for XYL as it has already been processed.
# Skipping Gradient Boosting for WSM as it has already been processed.
# Skipping Gradient Boosting for WMB as it has already been processed.
# Skipping Gradient Boosting for WST as it has already been processed.
# Skipping Gradient Boosting for XOM as it has already been processed.
# Skipping Gradient Boosting for WY as it has already been processed.
# Skipping Gradient Boosting for WFC as it has already been processed.
# Skipping Gradient Boosting for WTW as it has already been processed.
# Skipping Gradient Boosting for WDC as it has already been processed.
# Skipping Gradient Boosting for ZBH as it has already been processed.
# Skipping Gradient Boosting for WBD as it has already been processed.
# Skipping Gradient Boosting for WELL as it has already been processed.
# Skipping Gradient Boosting for WDAY as it has already been processed.
# Skipping Gradient Boosting for VZ as it has already been processed.
# Skipping Gradient Boosting for WAT as it has already been processed.
# Skipping Gradient Boosting for V as it has already been processed.
# Skipping Gradient Boosting for VEEV as it has already been processed.
# Skipping Gradient Boosting for URI as it has already been processed.
# Skipping Gradient Boosting for USB as it has already been processed.
# Skipping Gradient Boosting for VRTX as it has already been processed.
#
# Processing Gradient Boosting model for stock: TEAM
# Loaded existing Gradient Boosting study for TEAM.
# [W 2024-12-08 15:22:30,431] Trial 10 failed with parameters: {'n_estimators': 367, 'learning_rate': 0.024996199100290006, 'max_depth': 8, 'subsample': 0.7913202457019239, 'min_samples_split': 16} because of the following error: ValueError('Cannot have number of folds=6 greater than the number of samples=0.').
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "<ipython-input-37-1f9010b01bc7>", line 44, in objective_gb
#     for i, (train_index, test_index) in enumerate(tscv.split(X)):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py", line 1247, in _split
#     raise ValueError(
# ValueError: Cannot have number of folds=6 greater than the number of samples=0.
# [W 2024-12-08 15:22:30,435] Trial 10 failed with value None.
# An error occurred while processing Gradient Boosting for TEAM: Cannot have number of folds=6 greater than the number of samples=0.
# Saved Gradient Boosting parameters, forecasts, and performance data for TEAM.
# Skipping Gradient Boosting for TRGP as it has already been processed.
# Skipping Gradient Boosting for TFC as it has already been processed.
# Skipping Gradient Boosting for TSLA as it has already been processed.
# Skipping Gradient Boosting for TRMB as it has already been processed.
# Skipping Gradient Boosting for UNH as it has already been processed.
# Skipping Gradient Boosting for SPGI as it has already been processed.
# Skipping Gradient Boosting for SYF as it has already been processed.
# Skipping Gradient Boosting for TT as it has already been processed.
# Skipping Gradient Boosting for UNP as it has already been processed.
# Skipping Gradient Boosting for SYK as it has already been processed.
# Skipping Gradient Boosting for UPS as it has already been processed.
# Skipping Gradient Boosting for SYY as it has already been processed.
# Skipping Gradient Boosting for TGT as it has already been processed.
# Skipping Gradient Boosting for TAP as it has already been processed.
#
# Processing Gradient Boosting model for stock: TWLO
# Loaded existing Gradient Boosting study for TWLO.
# [W 2024-12-08 15:22:31,005] Trial 6 failed with parameters: {'n_estimators': 280, 'learning_rate': 0.16526281764853964, 'max_depth': 10, 'subsample': 0.6319601316884346, 'min_samples_split': 12} because of the following error: ValueError('Cannot have number of folds=6 greater than the number of samples=0.').
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "<ipython-input-37-1f9010b01bc7>", line 44, in objective_gb
#     for i, (train_index, test_index) in enumerate(tscv.split(X)):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py", line 1247, in _split
#     raise ValueError(
# ValueError: Cannot have number of folds=6 greater than the number of samples=0.
# [W 2024-12-08 15:22:31,006] Trial 6 failed with value None.
# An error occurred while processing Gradient Boosting for TWLO: Cannot have number of folds=6 greater than the number of samples=0.
# Saved Gradient Boosting parameters, forecasts, and performance data for TWLO.
# Skipping Gradient Boosting for TSCO as it has already been processed.
# Skipping Gradient Boosting for TXN as it has already been processed.
# Skipping Gradient Boosting for TRV as it has already been processed.
# Skipping Gradient Boosting for T as it has already been processed.
# Skipping Gradient Boosting for SBUX as it has already been processed.
# Skipping Gradient Boosting for PNC as it has already been processed.
# Skipping Gradient Boosting for QCOM as it has already been processed.
# Skipping Gradient Boosting for PTC as it has already been processed.
# Skipping Gradient Boosting for PPG as it has already been processed.
# Skipping Gradient Boosting for PWR as it has already been processed.
# Skipping Gradient Boosting for PRU as it has already been processed.
# Skipping Gradient Boosting for RCL as it has already been processed.
# Skipping Gradient Boosting for STE as it has already been processed.
# Skipping Gradient Boosting for SLB as it has already been processed.
# Skipping Gradient Boosting for SCHW as it has already been processed.
# Skipping Gradient Boosting for SBAC as it has already been processed.
# Skipping Gradient Boosting for PYPL as it has already been processed.
# Skipping Gradient Boosting for RTX as it has already been processed.
# Skipping Gradient Boosting for REGN as it has already been processed.
# Skipping Gradient Boosting for PSX as it has already been processed.
# Skipping Gradient Boosting for POOL as it has already been processed.
# Skipping Gradient Boosting for SNPS as it has already been processed.
# Skipping Gradient Boosting for PNR as it has already been processed.
# Skipping Gradient Boosting for RJF as it has already been processed.
# Skipping Gradient Boosting for PLD as it has already been processed.
# Skipping Gradient Boosting for PEG as it has already been processed.
# Skipping Gradient Boosting for PANW as it has already been processed.
# Skipping Gradient Boosting for PEP as it has already been processed.
# Skipping Gradient Boosting for PG as it has already been processed.
# Skipping Gradient Boosting for PHM as it has already been processed.
# Skipping Gradient Boosting for PFE as it has already been processed.
# Skipping Gradient Boosting for PGR as it has already been processed.
# Skipping Gradient Boosting for NFLX as it has already been processed.
# Skipping Gradient Boosting for NEE as it has already been processed.
# Skipping Gradient Boosting for ODFL as it has already been processed.
# Skipping Gradient Boosting for OC as it has already been processed.
# Skipping Gradient Boosting for NVDA as it has already been processed.
# Skipping Gradient Boosting for NI as it has already been processed.
# Skipping Gradient Boosting for OVV as it has already been processed.
# Skipping Gradient Boosting for NEM as it has already been processed.
# Skipping Gradient Boosting for NDAQ as it has already been processed.
# Skipping Gradient Boosting for MOS as it has already been processed.
# Skipping Gradient Boosting for ORCL as it has already been processed.
# Skipping Gradient Boosting for MRK as it has already been processed.
# Skipping Gradient Boosting for MU as it has already been processed.
# Skipping Gradient Boosting for NUE as it has already been processed.
# Skipping Gradient Boosting for OKE as it has already been processed.
# Skipping Gradient Boosting for NOW as it has already been processed.
# Skipping Gradient Boosting for NXPI as it has already been processed.
# Skipping Gradient Boosting for MMM as it has already been processed.
# Skipping Gradient Boosting for NTAP as it has already been processed.
# Skipping Gradient Boosting for NOC as it has already been processed.
# Skipping Gradient Boosting for MSTR as it has already been processed.
# Skipping Gradient Boosting for MS as it has already been processed.
# Skipping Gradient Boosting for LLY as it has already been processed.
# Skipping Gradient Boosting for LKQ as it has already been processed.
# Skipping Gradient Boosting for META as it has already been processed.
# Skipping Gradient Boosting for MKC as it has already been processed.
# Skipping Gradient Boosting for LH as it has already been processed.
# Skipping Gradient Boosting for MSFT as it has already been processed.
# Skipping Gradient Boosting for MMC as it has already been processed.
# Skipping Gradient Boosting for MLM as it has already been processed.
# Skipping Gradient Boosting for MET as it has already been processed.
# Skipping Gradient Boosting for MCO as it has already been processed.
# Skipping Gradient Boosting for MCD as it has already been processed.
# Skipping Gradient Boosting for MELI as it has already been processed.
# Skipping Gradient Boosting for MTD as it has already been processed.
# Skipping Gradient Boosting for LII as it has already been processed.
# Skipping Gradient Boosting for LIN as it has already been processed.
# Skipping Gradient Boosting for MCK as it has already been processed.
# Skipping Gradient Boosting for MSI as it has already been processed.
# Skipping Gradient Boosting for MRVL as it has already been processed.
# Skipping Gradient Boosting for IRM as it has already been processed.
# Skipping Gradient Boosting for KMI as it has already been processed.
# Skipping Gradient Boosting for LNG as it has already been processed.
# Skipping Gradient Boosting for JBHT as it has already been processed.
# Skipping Gradient Boosting for KEYS as it has already been processed.
# Skipping Gradient Boosting for LULU as it has already been processed.
# Skipping Gradient Boosting for KKR as it has already been processed.
# Skipping Gradient Boosting for LRCX as it has already been processed.
# Skipping Gradient Boosting for KMB as it has already been processed.
# Skipping Gradient Boosting for KR as it has already been processed.
# Skipping Gradient Boosting for J as it has already been processed.
# Skipping Gradient Boosting for KMX as it has already been processed.
# Skipping Gradient Boosting for IT as it has already been processed.
# Skipping Gradient Boosting for KO as it has already been processed.
# Skipping Gradient Boosting for LDOS as it has already been processed.
# Skipping Gradient Boosting for MA as it has already been processed.
# Skipping Gradient Boosting for LOW as it has already been processed.
# Skipping Gradient Boosting for ISRG as it has already been processed.
# Skipping Gradient Boosting for KHC as it has already been processed.
# Skipping Gradient Boosting for K as it has already been processed.
# Skipping Gradient Boosting for AMT as it has already been processed.
# Skipping Gradient Boosting for AAPL as it has already been processed.
# Skipping Gradient Boosting for BXP as it has already been processed.
# Skipping Gradient Boosting for BKNG as it has already been processed.
# Skipping Gradient Boosting for CAH as it has already been processed.
#
# Processing Gradient Boosting model for stock: ALNY
# Loaded existing Gradient Boosting study for ALNY.
# [W 2024-12-08 15:22:32,881] Trial 2 failed with parameters: {'n_estimators': 412, 'learning_rate': 0.03735068905825079, 'max_depth': 9, 'subsample': 0.5929253675374775, 'min_samples_split': 6} because of the following error: ValueError('Cannot have number of folds=6 greater than the number of samples=0.').
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "<ipython-input-37-1f9010b01bc7>", line 44, in objective_gb
#     for i, (train_index, test_index) in enumerate(tscv.split(X)):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py", line 1247, in _split
#     raise ValueError(
# ValueError: Cannot have number of folds=6 greater than the number of samples=0.
# [W 2024-12-08 15:22:32,886] Trial 2 failed with value None.
# An error occurred while processing Gradient Boosting for ALNY: Cannot have number of folds=6 greater than the number of samples=0.
# Saved Gradient Boosting parameters, forecasts, and performance data for ALNY.
# Skipping Gradient Boosting for AFL as it has already been processed.
# Skipping Gradient Boosting for ANET as it has already been processed.
# Skipping Gradient Boosting for BBY as it has already been processed.
# Skipping Gradient Boosting for ANSS as it has already been processed.
# Skipping Gradient Boosting for BALL as it has already been processed.
# Skipping Gradient Boosting for ACGL as it has already been processed.
# Skipping Gradient Boosting for AXON as it has already been processed.
# Skipping Gradient Boosting for BKR as it has already been processed.
# Skipping Gradient Boosting for AMD as it has already been processed.
# Skipping Gradient Boosting for AIZ as it has already been processed.
# Skipping Gradient Boosting for A as it has already been processed.
# Skipping Gradient Boosting for ABBV as it has already been processed.
# Skipping Gradient Boosting for AVGO as it has already been processed.
# Skipping Gradient Boosting for AMZN as it has already been processed.
# Skipping Gradient Boosting for AJG as it has already been processed.
# Skipping Gradient Boosting for BMY as it has already been processed.
# Skipping Gradient Boosting for ADI as it has already been processed.
# Skipping Gradient Boosting for AKAM as it has already been processed.
# Skipping Gradient Boosting for AMAT as it has already been processed.
# Skipping Gradient Boosting for C as it has already been processed.
# Skipping Gradient Boosting for APD as it has already been processed.
# Skipping Gradient Boosting for ADBE as it has already been processed.
# Skipping Gradient Boosting for CAG as it has already been processed.
# Skipping Gradient Boosting for AXP as it has already been processed.
# Skipping Gradient Boosting for BG as it has already been processed.
# Skipping Gradient Boosting for BR as it has already been processed.
# Skipping Gradient Boosting for ADP as it has already been processed.
# Skipping Gradient Boosting for BAC as it has already been processed.
# Skipping Gradient Boosting for ADSK as it has already been processed.
# Skipping Gradient Boosting for AMGN as it has already been processed.
# Skipping Gradient Boosting for AON as it has already been processed.
# Skipping Gradient Boosting for BLK as it has already been processed.
# Skipping Gradient Boosting for BK as it has already been processed.
# Skipping Gradient Boosting for AMP as it has already been processed.
# Skipping Gradient Boosting for CLX as it has already been processed.
# Skipping Gradient Boosting for CPB as it has already been processed.
# Skipping Gradient Boosting for CI as it has already been processed.
# Skipping Gradient Boosting for EXC as it has already been processed.
# Skipping Gradient Boosting for FANG as it has already been processed.
# Skipping Gradient Boosting for CPRT as it has already been processed.
# Skipping Gradient Boosting for FFIV as it has already been processed.
# Skipping Gradient Boosting for DLR as it has already been processed.
# Skipping Gradient Boosting for ETN as it has already been processed.
# Skipping Gradient Boosting for EQT as it has already been processed.
# Skipping Gradient Boosting for EW as it has already been processed.
# Skipping Gradient Boosting for CNC as it has already been processed.
# Skipping Gradient Boosting for COO as it has already been processed.
# Skipping Gradient Boosting for CMCSA as it has already been processed.
# Skipping Gradient Boosting for CSCO as it has already been processed.
# Skipping Gradient Boosting for ES as it has already been processed.
# Skipping Gradient Boosting for FDX as it has already been processed.
# Skipping Gradient Boosting for DE as it has already been processed.
# Skipping Gradient Boosting for CMS as it has already been processed.
# Skipping Gradient Boosting for EQIX as it has already been processed.
# Skipping Gradient Boosting for CRH as it has already been processed.
# Skipping Gradient Boosting for ECL as it has already been processed.
# Skipping Gradient Boosting for COR as it has already been processed.
# Skipping Gradient Boosting for CHD as it has already been processed.
# Skipping Gradient Boosting for CBRE as it has already been processed.
# Skipping Gradient Boosting for EXPD as it has already been processed.
# Skipping Gradient Boosting for CMG as it has already been processed.
# Skipping Gradient Boosting for CRM as it has already been processed.
# Skipping Gradient Boosting for D as it has already been processed.
# Skipping Gradient Boosting for COST as it has already been processed.
# Skipping Gradient Boosting for DAL as it has already been processed.
# Skipping Gradient Boosting for FERG as it has already been processed.
# Skipping Gradient Boosting for DFS as it has already been processed.
# Skipping Gradient Boosting for FDS as it has already been processed.
# Skipping Gradient Boosting for DECK as it has already been processed.
# Skipping Gradient Boosting for EIX as it has already been processed.
# Skipping Gradient Boosting for CCK as it has already been processed.
# Skipping Gradient Boosting for CHRW as it has already been processed.
# Skipping Gradient Boosting for CNH as it has already been processed.
# Skipping Gradient Boosting for CVX as it has already been processed.
# Skipping Gradient Boosting for FBIN as it has already been processed.
# Skipping Gradient Boosting for DXCM as it has already been processed.
# Skipping Gradient Boosting for DGX as it has already been processed.
# Skipping Gradient Boosting for EA as it has already been processed.
# Skipping Gradient Boosting for CDNS as it has already been processed.
# Skipping Gradient Boosting for CMI as it has already been processed.
# Skipping Gradient Boosting for ELV as it has already been processed.
# Skipping Gradient Boosting for FI as it has already been processed.
# Skipping Gradient Boosting for DHR as it has already been processed.
# Skipping Gradient Boosting for CAT as it has already been processed.
# Skipping Gradient Boosting for CCI as it has already been processed.
# Skipping Gradient Boosting for COP as it has already been processed.
# Skipping Gradient Boosting for EME as it has already been processed.
# Skipping Gradient Boosting for DIS as it has already been processed.
# Skipping Gradient Boosting for COF as it has already been processed.
# Skipping Gradient Boosting for JNPR as it has already been processed.
# Skipping Gradient Boosting for IDXX as it has already been processed.
# Skipping Gradient Boosting for GWW as it has already been processed.
# Skipping Gradient Boosting for INTC as it has already been processed.
#
# Processing Gradient Boosting model for stock: HUBS
# Loaded existing Gradient Boosting study for HUBS.
# [W 2024-12-08 15:22:33,626] Trial 1 failed with parameters: {'n_estimators': 291, 'learning_rate': 0.03023815564873973, 'max_depth': 7, 'subsample': 0.5132281455018759, 'min_samples_split': 17} because of the following error: ValueError('Cannot have number of folds=6 greater than the number of samples=0.').
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "<ipython-input-37-1f9010b01bc7>", line 44, in objective_gb
#     for i, (train_index, test_index) in enumerate(tscv.split(X)):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py", line 1247, in _split
#     raise ValueError(
# ValueError: Cannot have number of folds=6 greater than the number of samples=0.
# [W 2024-12-08 15:22:33,628] Trial 1 failed with value None.
# An error occurred while processing Gradient Boosting for HUBS: Cannot have number of folds=6 greater than the number of samples=0.
# Saved Gradient Boosting parameters, forecasts, and performance data for HUBS.
# Skipping Gradient Boosting for HOLX as it has already been processed.
# Skipping Gradient Boosting for FTV as it has already been processed.
# Skipping Gradient Boosting for HBAN as it has already been processed.
# Skipping Gradient Boosting for HD as it has already been processed.
# Skipping Gradient Boosting for HCA as it has already been processed.
# Skipping Gradient Boosting for FLUT as it has already been processed.
# Skipping Gradient Boosting for HES as it has already been processed.
# Skipping Gradient Boosting for GOOGL as it has already been processed.
# Skipping Gradient Boosting for JNJ as it has already been processed.
# Skipping Gradient Boosting for HON as it has already been processed.
# Skipping Gradient Boosting for JCI as it has already been processed.
# Skipping Gradient Boosting for HUBB as it has already been processed.
# Skipping Gradient Boosting for GDDY as it has already been processed.
# Skipping Gradient Boosting for GILD as it has already been processed.
# Skipping Gradient Boosting for HUM as it has already been processed.
# Skipping Gradient Boosting for IBM as it has already been processed.
# Skipping Gradient Boosting for GE as it has already been processed.
# Skipping Gradient Boosting for FSLR as it has already been processed.
# Skipping Gradient Boosting for FIS as it has already been processed.
# Skipping Gradient Boosting for HRL as it has already been processed.
# Skipping Gradient Boosting for FICO as it has already been processed.
# Skipping Gradient Boosting for HPE as it has already been processed.
# Skipping Gradient Boosting for IP as it has already been processed.
# Skipping Gradient Boosting for INTU as it has already been processed.
# Skipping Gradient Boosting for IQV as it has already been processed.
# Skipping Gradient Boosting for JPM as it has already been processed.
# Skipping Gradient Boosting for HIG as it has already been processed.
# Skipping Gradient Boosting for GS as it has already been processed.
# Skipping Gradient Boosting for HLT as it has already been processed.
# Skipping Gradient Boosting for HPQ as it has already been processed.
# Skipping Gradient Boosting for IEX as it has already been processed.
# Skipping Gradient Boosting for GIS as it has already been processed.
#
# Gradient Boosting model training and forecasting completed.

# %%
# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import pickle

# Define paths
DATA_PATH = '/content/drive/MyDrive/data/'
STUDIES_DIR = os.path.join(DATA_PATH, 'optuna_studies')
FORECASTS_PATH = os.path.join(DATA_PATH, 'stock_forecasts.pkl')
PERFORMANCE_PATH = os.path.join(DATA_PATH, 'model_performance.pkl')
BEST_PARAMS_PATH = os.path.join(DATA_PATH, 'best_params_dict.pkl')

# Load existing forecasts and performance data
with open(FORECASTS_PATH, 'rb') as f:
    stock_forecasts = pickle.load(f)

with open(PERFORMANCE_PATH, 'rb') as f:
    model_performance = pickle.load(f)

# List of all stocks processed
all_stocks = list(stock_data.keys())

# Identify inadequate stocks based on performance data
inadequate_stocks = []
adequate_stocks = []

for stock in all_stocks:
    # Check if the stock has a forecast and RMSE
    if stock in stock_forecasts and 'GradientBoosting' in stock_forecasts[stock]:
        # Further check if RMSE is not None (indicating successful processing)
        performance = next((item for item in model_performance if item['Stock'] == stock and item['Model'] == 'GradientBoosting'), None)
        if performance and performance['RMSE'] is not None:
            adequate_stocks.append(stock)
        else:
            inadequate_stocks.append(stock)
    else:
        inadequate_stocks.append(stock)

print(f"Total Stocks: {len(all_stocks)}")
print(f"Number of Adequate Stocks: {len(adequate_stocks)}")
print(f"Number of Inadequate Stocks: {len(inadequate_stocks)}")
print("\nList of Inadequate Stocks:")
print(inadequate_stocks)
# Out:
# Total Stocks: 260
# Number of Adequate Stocks: 256
# Number of Inadequate Stocks: 4
#
# List of Inadequate Stocks:
# ['TEAM', 'TWLO', 'ALNY', 'HUBS']

# %%
# %%
# Initialize a list to store profit calculations
profit_list = []

for stock in adequate_stocks:
    try:
        # Retrieve the forecasted price
        forecast_price = stock_forecasts[stock]['GradientBoosting']

        # Get the current Close price (last available in the DataFrame)
        current_price = stock_data[stock]['Close'].iloc[-1]

        # Calculate the number of shares purchasable with £30
        num_shares = 30 / current_price

        # Calculate forecasted investment value
        forecast_value = num_shares * forecast_price

        # Calculate expected profit
        expected_profit = forecast_value - 30

        # Append a dictionary to the list
        profit_list.append({
            'Stock': stock,
            'Current_Price': round(current_price, 2),
            'Forecasted_Price': round(forecast_price, 2),
            'Expected_Profit': round(expected_profit, 2)
        })
    except Exception as e:
        print(f"Error processing stock {stock}: {e}")
        # Optionally, log the error or mark the stock as inadequate
        inadequate_stocks.append(stock)

# Convert the list of dictionaries to a DataFrame
profit_df = pd.DataFrame(profit_list)

# Sort the DataFrame by Expected Profit in descending order
profit_df.sort_values(by='Expected_Profit', ascending=False, inplace=True)

# Reset index
profit_df.reset_index(drop=True, inplace=True)

# Display the profit DataFrame
profit_df
# Out:
#     Stock  Current_Price  Forecasted_Price  Expected_Profit
# 0     SLB          43.66             43.82             0.11
# 1    KEYS         168.61            169.00             0.07
# 2    AKAM          93.86             93.96             0.03
# 3     ADI         217.17            217.40             0.03
# 4     ZBH         112.02            112.12             0.03
# ..    ...            ...               ...              ...
# 251   COO         103.43            103.33            -0.03
# 252  NXPI         226.53            226.31            -0.03
# 253   MCO         500.88            500.36            -0.03
# 254  EQIX         979.10            978.03            -0.03
# 255  LULU         319.52            318.86            -0.06
#
# [256 rows x 4 columns]
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
# %%
# Total Investment
total_investment = 30  # in GBP

# Calculate the total expected profit of all adequate stocks
total_expected_profit = profit_df['Expected_Profit'].sum()

# Calculate the weight (allocation percentage) for each stock based on its expected profit
profit_df['Weight'] = profit_df['Expected_Profit'] / total_expected_profit

# Calculate the investment allocation for each stock
profit_df['Investment'] = profit_df['Weight'] * total_investment

# Calculate the number of shares for each stock
profit_df['Number_of_Shares'] = profit_df['Investment'] / profit_df['Current_Price']

# Calculate the expected profit for the allocated investment
profit_df['Allocated_Profit'] = profit_df['Number_of_Shares'] * (profit_df['Forecasted_Price'] - profit_df['Current_Price'])

# Round the numerical columns for better readability
profit_df[['Investment', 'Number_of_Shares', 'Allocated_Profit']] = profit_df[['Investment', 'Number_of_Shares', 'Allocated_Profit']].round(2)

# Display the updated DataFrame with allocations
profit_df[['Stock', 'Current_Price', 'Forecasted_Price', 'Expected_Profit', 'Investment', 'Number_of_Shares', 'Allocated_Profit']]
# Out:
#     Stock  Current_Price  Forecasted_Price  Expected_Profit  Investment  \
# 0     SLB          43.66             43.82             0.11      -30.00
# 1    KEYS         168.61            169.00             0.07      -19.09
# 2    AKAM          93.86             93.96             0.03       -8.18
# 3     ADI         217.17            217.40             0.03       -8.18
# 4     ZBH         112.02            112.12             0.03       -8.18
# ..    ...            ...               ...              ...         ...
# 251   COO         103.43            103.33            -0.03        8.18
# 252  NXPI         226.53            226.31            -0.03        8.18
# 253   MCO         500.88            500.36            -0.03        8.18
# 254  EQIX         979.10            978.03            -0.03        8.18
# 255  LULU         319.52            318.86            -0.06       16.36
#
#      Number_of_Shares  Allocated_Profit
# 0               -0.69             -0.11
# 1               -0.11             -0.04
# 2               -0.09             -0.01
# 3               -0.04             -0.01
# 4               -0.07             -0.01
# ..                ...               ...
# 251              0.08             -0.01
# 252              0.04             -0.01
# 253              0.02             -0.01
# 254              0.01             -0.01
# 255              0.05             -0.03
#
# [256 rows x 7 columns]

# %%
# %%
# Final Ranked List with Investment Strategy
final_ranking = profit_df[['Stock', 'Current_Price', 'Forecasted_Price', 'Expected_Profit', 'Investment', 'Number_of_Shares', 'Allocated_Profit']].copy()

# Calculate the total allocated investment and total expected profit
total_allocated_investment = final_ranking['Investment'].sum()
total_allocated_profit = final_ranking['Allocated_Profit'].sum()

# Display the final ranking
print("Final Ranked List of Stocks Based on Expected Profit:")
display(final_ranking)

print(f"Total Allocated Investment: £{round(total_allocated_investment, 2)}")
print(f"Total Expected Profit: £{round(total_allocated_profit, 2)}")
# Out:
# Final Ranked List of Stocks Based on Expected Profit:
#     Stock  Current_Price  Forecasted_Price  Expected_Profit  Investment  \
# 0     SLB          43.66             43.82             0.11      -30.00
# 1    KEYS         168.61            169.00             0.07      -19.09
# 2    AKAM          93.86             93.96             0.03       -8.18
# 3     ADI         217.17            217.40             0.03       -8.18
# 4     ZBH         112.02            112.12             0.03       -8.18
# ..    ...            ...               ...              ...         ...
# 251   COO         103.43            103.33            -0.03        8.18
# 252  NXPI         226.53            226.31            -0.03        8.18
# 253   MCO         500.88            500.36            -0.03        8.18
# 254  EQIX         979.10            978.03            -0.03        8.18
# 255  LULU         319.52            318.86            -0.06       16.36
#
#      Number_of_Shares  Allocated_Profit
# 0               -0.69             -0.11
# 1               -0.11             -0.04
# 2               -0.09             -0.01
# 3               -0.04             -0.01
# 4               -0.07             -0.01
# ..                ...               ...
# 251              0.08             -0.01
# 252              0.04             -0.01
# 253              0.02             -0.01
# 254              0.01             -0.01
# 255              0.05             -0.03
#
# [256 rows x 7 columns]
# Total Allocated Investment: £30.0
# Total Expected Profit: £-0.26

# %%
# %%
# Display Inadequate Stocks
if inadequate_stocks:
    inadequate_df = pd.DataFrame({'Inadequate Stocks': inadequate_stocks})
    print("List of Inadequate Stocks (Excluded from Analysis):")
    display(inadequate_df)
else:
    print("No Inadequate Stocks found.")
# Out:
# List of Inadequate Stocks (Excluded from Analysis):
#   Inadequate Stocks
# 0              TEAM
# 1              TWLO
# 2              ALNY
# 3              HUBS

# %%
# %%
# Summary
print("### Investment Strategy Summary ###\n")

print(f"**Total Investment Available:** £{total_investment}\n")
print(f"**Total Expected Profit:** £{round(total_allocated_profit, 2)}\n")
print("**Portfolio Allocation:**")
display(final_ranking[['Stock', 'Investment', 'Number_of_Shares', 'Allocated_Profit']])

if inadequate_stocks:
    print("\n**Inadequate Stocks (Excluded from Portfolio):**")
    display(inadequate_df)
else:
    print("\nAll stocks were adequate for the analysis.")
# Out:
# ### Investment Strategy Summary ###
#
# **Total Investment Available:** £30
#
# **Total Expected Profit:** £-0.26
#
# **Portfolio Allocation:**
#     Stock  Investment  Number_of_Shares  Allocated_Profit
# 0     SLB      -30.00             -0.69             -0.11
# 1    KEYS      -19.09             -0.11             -0.04
# 2    AKAM       -8.18             -0.09             -0.01
# 3     ADI       -8.18             -0.04             -0.01
# 4     ZBH       -8.18             -0.07             -0.01
# ..    ...         ...               ...               ...
# 251   COO        8.18              0.08             -0.01
# 252  NXPI        8.18              0.04             -0.01
# 253   MCO        8.18              0.02             -0.01
# 254  EQIX        8.18              0.01             -0.01
# 255  LULU       16.36              0.05             -0.03
#
# [256 rows x 4 columns]
# **Inadequate Stocks (Excluded from Portfolio):**
#   Inadequate Stocks
# 0              TEAM
# 1              TWLO
# 2              ALNY
# 3              HUBS

# %%
# %%
# Define the allocation function
def allocate_investment(profit_df, total_investment=30):
    """
    Allocates the total investment to the stock(s) with the highest expected profit.

    Parameters:
    - profit_df (pd.DataFrame): DataFrame containing 'Stock', 'Expected_Profit'.
    - total_investment (float): Total amount to invest.

    Returns:
    - allocation (dict): Dictionary with 'Stock', 'Investment', 'Expected_Profit'.
    - total_profit (float): Total expected profit from the investment.
    """
    if profit_df.empty:
        print("No adequate stocks available for investment.")
        return None, 0.0

    # Sort the DataFrame by Expected Profit in descending order
    sorted_df = profit_df.sort_values(by='Expected_Profit', ascending=False).reset_index(drop=True)

    # Select the top stock
    top_stock = sorted_df.iloc[0]

    # Allocate the entire investment to the top stock
    allocation = {
        'Stock': top_stock['Stock'],
        'Investment': round(total_investment, 2),
        'Expected_Profit': round(top_stock['Expected_Profit'], 2)
    }

    # Total profit is the expected profit from the top stock
    total_profit = allocation['Expected_Profit']

    return allocation, total_profit

# %%
# Allocate investment
allocation, total_profit = allocate_investment(profit_df, total_investment=30)

if allocation:
    # Create a DataFrame for allocation
    allocation_df = pd.DataFrame([allocation])

    print("### Investment Allocation ###\n")
    display(allocation_df)

    print(f"**Total Investment:** £{allocation['Investment']}")
    print(f"**Total Expected Profit:** £{total_profit}")
else:
    print("No allocation made due to lack of adequate stocks.")

# %%
# Display Inadequate Stocks
if inadequate_stocks:
    inadequate_df = pd.DataFrame({'Inadequate Stocks': inadequate_stocks})
    print("### Inadequate Stocks (Excluded from Analysis) ###")
    display(inadequate_df)
else:
    print("No Inadequate Stocks found.")

# %%
# Summary of Investment Strategy
if allocation:
    print("### Investment Strategy Summary ###\n")

    print(f"**Total Investment Available:** £{allocation['Investment']}\n")
    print(f"**Total Expected Profit:** £{allocation['Expected_Profit']}\n")
    print("**Portfolio Allocation:**")
    display(allocation_df[['Stock', 'Investment', 'Expected_Profit']])
else:
    print("No investment allocation was made due to lack of adequate stocks.")
# Out:
# ### Investment Allocation ###
#   Stock  Investment  Expected_Profit
# 0   SLB          30             0.11
# **Total Investment:** £30
# **Total Expected Profit:** £0.11
# ### Inadequate Stocks (Excluded from Analysis) ###
#   Inadequate Stocks
# 0              TEAM
# 1              TWLO
# 2              ALNY
# 3              HUBS
# ### Investment Strategy Summary ###
#
# **Total Investment Available:** £30
#
# **Total Expected Profit:** £0.11
#
# **Portfolio Allocation:**
#   Stock  Investment  Expected_Profit
# 0   SLB          30             0.11
